# %% [markdown]
# # Bering Sea with flexible biology: application setup
#
# This script builds a working ROMS application environment with the following components:
#
#  - Grid: Bering10K
#  - Ocean model: nonlinear
#  - Ice model: Budgell (Hedstrom version)
#  - Biogeochemical models:
#    - BEST_NPZ
#    - BIO_COBALT
#    - BIO_BANAS

# %%
import os
import sys
import yaml
from collections import OrderedDict

sys.path.insert(0, '/Users/kakearney/Documents/PythonCodeKAK/roms_input_wrangler')

import varinfo
import standard_input as si

# %% [markdown]
# ## Header file
#
# The header file combines the defaults for the Bering_10K application along with all biological module options.  The bio-dependent flags are wrapped in a conditional such that the specific module to be compiled is turned on by the compilation script (build_roms.bash).  This allows the same header file to be used for all app compilation variants.  Ideally, the final header file should not be unless major changes are made to the Bering_10K ocean model configuration or one of the biogeochemical models.

# %%
newfile = "test_bering_10k.h"

berapps = "../.."
header_subfiles = [os.path.join(berapps, "subApps", "BERING_10K_new", "bering_10k.h"), 
                   os.path.join(berapps, "subApps", "BIO_COBALT",     "cobalt_cpp.h"), 
                   os.path.join(berapps, "subApps", "BEST_NPZ",       "bestnpz_cpp.h"),
                   os.path.join(berapps, "subApps", "BIO_BANAS",      "banas_cpp.h")]

# Concatenate sub-files into new header file

with open(newfile, 'w') as out:

    for file in header_subfiles:
        with open(file, 'r') as f:
            contents = f.read()
            out.write(contents)

# %% [markdown]
# ## varinfo.dat
#
# We build several different versions of the varinfo.dat file, to be used with different compiled versions.  The physics-only option combines I/O details for ocean and ice variables.  Each biological model adds biological I/O details to that physics-only option.  These are kept separate to ensure no variable conflicts occur between BGC options.

# %%
# Read default ocean I/O (note: variables organized into many topic arrays)

with open(os.path.join(berapps, "subApps", "ocean", "default_io.yaml"), 'r') as f:
    Vphys = yaml.load(f)

# Ice and BGC I/O files only hold a single metadata array, so read with varinfo.readfile wrapper to extract just that
    
Vice = varinfo.readfile(os.path.join(berapps, "subApps", "IceBudgell", "ice_io.yaml"),     type="yaml")

Vbes = varinfo.readfile(os.path.join(berapps, "subApps", "BEST_NPZ",   "bestnpz_io.yaml"), type="yaml")
Vcob = varinfo.readfile(os.path.join(berapps, "subApps", "BIO_COBALT", "cobalt_io.yaml"),  type="yaml")
Vban = varinfo.readfile(os.path.join(berapps, "subApps", "BIO_BANAS",  "banas_io.yaml"),   type="yaml")

# Combine physics variables (splitting based on where bio variables will be inserted)

V1 = Vphys['state_variables'] + \
     Vphys['wet_dry_masks'] + \
     Vphys['detided'] + \
     Vphys['momentum'] + \
     Vphys['tracer_flux'] + \
     Vphys['mixing'] + \
     Vphys['boundary'] + \
     Vphys['atmos_forcing'] + \
     Vphys['tidal_forcing'] + \
     Vphys['river_forcing'] + \
     Vphys['boundary_layer'] + \
     Vphys['climatology'] + \
     Vphys['adjoint'] + \
     Vphys['tangent'] + \
     Vphys['observation_vars'] + \
     Vphys['passive'] + \
     Vphys['sediment']
        
V2 = Vphys['quadratic'] + \
     Vphys['diagnostic'] + \
     Vphys['forward_trajectory'] + \
     Vphys['assimilation']

    
# Rename bottom drag coefficient (in sediment) to match Bering10K grid file (rdrag -> rdrag_grid)

for ii in V1:
    if ii['index_code'] == "idragL":
        ii['variable'] = "rdrag_grid"
        
# Combine ocean and ice I/O

Vbase = V1 + V2 + Vice

# Combine with bio options.  Note that bio state variables need to preceed any variable 
# that includes (itrc) in their ID (e.g. tracer2 and others in quadratic set). I opt to 
# place all tracers together just before quadratic terms, and other bio variables at the end.

trc = [];
oth = []
for ii in Vbes:
    if ii['index_code'].startswith('idTvar(') | \
       ii['index_code'].startswith('idBeTvar(') | \
       ii['index_code'].startswith('idBeTvar('):
        trc.append(ii)
    else:
        oth.append(ii)
        
Vbes = V1 + trc + V2 + Vice + oth


trc = [];
oth = []
for ii in Vcob:
    if ii['index_code'].startswith('idTvar(') | \
       ii['index_code'].startswith('idBeTvar(') | \
       ii['index_code'].startswith('idBeTvar('):
        trc.append(ii)
    else:
        oth.append(ii)
        
Vcob = V1 + trc + V2 + Vice + oth

trc = [];
oth = []
for ii in Vban:
    if ii['index_code'].startswith('idTvar(') | \
       ii['index_code'].startswith('idBeTvar(') | \
       ii['index_code'].startswith('idBeTvar('):
        trc.append(ii)
    else:
        oth.append(ii)
        
Vban = V1 + trc + V2 + Vice + oth

# Write to files (classic format)

varinfo.writefile(Vbase, "test_varinfo_phys.dat",    type="classic")
varinfo.writefile(Vbes,  "test_varinfo_bestnpz.dat", type="classic")
varinfo.writefile(Vcob,  "test_varinfo_cobalt.dat",  type="classic")
varinfo.writefile(Vban,  "test_varinfo_banas.dat",   type="classic")

# %% [markdown]
# ## Input file templates

# %%
with open(os.path.join(berapps, "subApps", "BERING_10K_new","ocean_bering10k_new.in.yaml"), 'r') as f:
    test = si.ordered_load(f)

# %%
# bpardict testing

# paramfile = os.path.join(berapps, "subApps", "BIO_BANAS", "banas_parameters.yaml")
# iofile = os.path.join(berapps, "subApps", "BIO_BANAS", "banas_io.yaml")

paramfile = os.path.join(berapps, "subApps", "BEST_NPZ", "bestnpz_parameters.yaml")
iofile = os.path.join(berapps, "subApps", "BEST_NPZ", "bestnpz_io.yaml")

# Read parameters

P = yaml.load(open(paramfile))
Io = yaml.load(open(iofile))
Io = Io['metadata']

# Start dict with parameters

a = OrderedDict();
a['Lbiology'] = True
a['BioIter'] = 1

# print(yaml.dump({'Lbiology': True}))
# print(yaml.dump({'BioIter': 1}))

for ii in P:
    a[ii['param']] = ii['value']
    

    
# # Add extras

# nbt = 0
# nben = 0
# nice = 0
# for ii in Io:
#     if ii['index_code'].startswith('idTvar('):
#         nbt+=1
#     elif ii['index_code'].startswith('idBeTvar('):
#         nben+=1
#     elif ii['index_code'].startswith('idIceTvar('):
#         nice+=1

yaml.add_representer(OrderedDict, lambda dumper, data: dumper.represent_mapping('tag:yaml.org,2002:map', data.items()))

print(yaml.dump(a, default_flow_style=False))
# Out:
# Lbiology: true
# BioIter: 1
# PARfrac: 0.42
# k_ext: 0.034
# k_chlA: 0.0518
# k_chlB: 0.428
# k_chlC: 0.0363
# k_sed1: 2.833
# k_sed2: -1.079
# xi: 0.0126
# ccr: 65.0
# ccrPhL: 25.0
# FeC: 0.0001667
# DiS: 0.5
# DiL: 1.0
# DpS: 0.0275
# DpL: 0.0275
# alphaPhS: 5.6
# alphaPhL: 2.2
# k1PhS: 1.0
# k1PhL: 2.0
# k2PhS: 0.5
# k2PhL: 2.0
# FeCritPS: 2.0
# FeCritPL: 2.0
# kfePhS: 0.3
# kfePhL: 1.0
# fpPhSMZL: 1.0
# fpPhLMZL: 0.2
# fpPhSCop: 0.8
# fpPhLCop: 0.7
# fpMZLCop: 0.5
# fpPhSNCa: 0.1
# fpPhLNCa: 1.0
# fpMZLNCa: 1.0
# fpPhSEup: 1.0
# fpPhLEup: 1.0
# fpMZLEup: 1.0
# fpCopEup: 0.2
# fpDetEup: 0.4
# fpDetEupO: 0.0
# fpCopJel: 1.0
# fpNCaJel: 1.0
# fpEupJel: 1.0
# eMZL: 0.4
# eCop: 0.4
# eNCa: 0.3
# eEup: 0.3
# eJel: 0.069
# Q10MZL: 2.0
# Q10Cop: 1.7
# Q10NCa: 1.6
# Q10Eup: 1.5
# Q10Jele: 2.4
# Q10MZLT: 5.0
# Q10CopT: 5.0
# Q10NCaT: 5.0
# Q10EupT: 5.0
# Q10JelTe: 10.0
# fMZL: 20.0
# fCop: 30.0
# fNCa: 30.0
# fEup: 40.0
# fJel: 0.01
# gammaMZL: 0.7
# gammaCop: 0.7
# gammaNCa: 0.7
# gammaEup: 0.7
# gammaJel: 1.0
# mPhS: 0.01
# mPhL: 0.01
# mMZL: 0.0
# mpredMZL: 0.01
# mpredCop: 0.05
# mpredNCa: 0.05
# mpredEup: 0.05
# mpredJel: 0.006
# wPhS: 0.05
# wPhL: 1.0
# wDet: 1.0
# wDetF: 10.0
# respPhS: 0.02
# respPhL: 0.02
# respMZL: 0.08
# respCop: 0.04
# respNCa: 0.03
# respEup: 0.02
# respJel: 0.02
# Q10Jelr: 2.8
# Q10JelTr: 10.0
# KtBm_PhS: 0.03
# KtBm_PhL: 0.03
# KtBm_MZL: 0.069
# ktbmC: 0.05
# ktbmN: 0.05
# ktbmE: 0.069
# TmaxPhS: 10.0
# TmaxPhL: 10.0
# TmaxMZL: 8.0
# TrefC: 15.0
# TrefN: 5.0
# TrefE: 5.0
# Feinlo: 2.0
# Feinhi: 4.0
# Feinh: 20.0
# Feofflo: 0.01
# Feoffhi: 2.0
# Feoffh: 100.0
# wNCrise: 12.0
# wNCsink: 11.0
# RiseStart: 0.0
# RiseEnd: 60.0
# SinkStart: 155.0
# SinkEnd: 366.0
# RiseStartCM: 0.0
# RiseEndCM: 0.0
# SinkStartCM: 0.0
# SinkEndCM: 0.0
# Pv0: 0.1
# PvT: 0.069
# Nitr0: 0.0107
# ktntr: 0.002
# KNH4Nit: 0.057
# ToptNtr: 20.0
# q10r: 1.5
# Rup: 0.05
# KupD: 2000.0
# KupP: 10.0
# LupD: 292.0
# LupP: 1.0
# Qres: 0.25
# Rres: 0.0027
# rmort: 0.0021
# eex: 0.3
# eexD: 0.5
# prefD: 1.0
# prefPL: 1.0
# prefPS: 0.1
# T0benr: 5.0
# BenPred: 1.0e-06
# alphaIb: 0.8
# betaI: 0.018
# inhib: 1.46
# ksnut1: 1.0
# ksnut2: 4.0
# mu0: 2.4
# R0i: 0.05
# rg0: 0.01
# rg: 0.03
# annit: 0.0149
# aidz: 0.02
# tI0: 0.0095
# KI: 4.0

# %%
P
# Out:
# {'metadata': [{'descrip': 'Fraction of irradiance that is photosynthetically available (PAR)',
#    'param': 'PARfrac',
#    'unit': 'unitless',
#    'value': 0.42},
#   {'descrip': 'Clear-water attenuation coefficient',
#    'param': 'k_ext',
#    'unit': 'm^-1',
#    'value': 0.034},
#   {'descrip': 'Chlorophyll attenuation coefficient, factor',
#    'param': 'k_chlA',
#    'unit': 'm^-1',
#    'value': 0.0518},
#   {'descrip': 'Chlorophyll attenuation coefficient, exponent',
#    'param': 'k_chlB',
#    'unit': 'unitless',
#    'value': 0.428},
#   {'descrip': 'Other material (CDOM,sediment,etc.) attenuation coefficient',
#    'param': 'k_chlC',
#    'unit': 'm^-1',
#    'value': 0.0363},
#   {'descrip': 'Depth-based attenuation coefficient, factor',
#    'param': 'k_sed1',
#    'unit': 'm^-1',
#    'value': 2.833},
#   {'descrip': 'Depth-based attenuation coefficient, exponent',
#    'param': 'k_sed2',
#    'unit': 'unitless',
#    'value': -1.079},
#   {'descrip': 'Nitrogen:Carbon ratio',
#    'param': 'xi',
#    'unit': 'mmol N / mg C',
#    'value': 0.0126},
#   {'descrip': 'Carbon:Chlorophyll ratio, small phyto',
#    'param': 'ccr',
#    'unit': 'mg C / mg Chl-a',
#    'value': 65.0},
#   {'descrip': 'Carbon:Chlorophyll ratio, large phyto',
#    'param': 'ccrPhL',
#    'unit': 'mg C / mg Chl-a',
#    'value': 25.0},
#   {'descrip': 'Fe:Carbon ratio',
#    'param': 'FeC',
#    'unit': 'umol Fe / mg C',
#    'value': 0.0001667},
#   {'descrip': 'Doubling rate parameter',
#    'param': 'DiS',
#    'unit': 'd^-1',
#    'value': 0.5},
#   {'descrip': 'Doubling rate parameter',
#    'param': 'DiL',
#    'unit': 'd^-1',
#    'value': 1.0},
#   {'descrip': 'Doubling rate exponent',
#    'param': 'DpS',
#    'unit': 'degC^-1',
#    'value': 0.0275},
#   {'descrip': 'Doubling rate exponent',
#    'param': 'DpL',
#    'unit': 'degC^-1',
#    'value': 0.0275},
#   {'descrip': 'photosynthetic efficiency',
#    'param': 'alphaPhS',
#    'unit': 'mg C m^2 (mg Chl-a)^-1 (E^-1)',
#    'value': 5.6},
#   {'descrip': 'photosynthetic efficiency',
#    'param': 'alphaPhL',
#    'unit': 'mg C m^2 (mg Chl-a)^-1 (E^-1)',
#    'value': 2.2},
#   {'descrip': 'Half-saturation constant for NO3 limitation',
#    'param': 'k1PhS',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'Half-saturation constant for NO3 limitation',
#    'param': 'k1PhL',
#    'unit': None,
#    'value': 2.0},
#   {'descrip': 'Half-saturation constant for NH4 limitation',
#    'param': 'k2PhS',
#    'unit': None,
#    'value': 0.5},
#   {'descrip': 'Half-saturation constant for NH4 limitation',
#    'param': 'k2PhL',
#    'unit': None,
#    'value': 2.0},
#   {'descrip': 'Threshold below which PhS is limited',
#    'param': 'FeCritPS',
#    'unit': 'umol Fe m^-3',
#    'value': 2.0},
#   {'descrip': 'Threshold below which PhS is limited',
#    'param': 'FeCritPL',
#    'unit': 'umol Fe m^-3',
#    'value': 2.0},
#   {'descrip': 'Half-saturation constant for Fe',
#    'param': 'kfePhS',
#    'unit': 'umol m^-3',
#    'value': 0.3},
#   {'descrip': 'Half-saturation constant for Fe',
#    'param': 'kfePhL',
#    'unit': 'umol m^-3',
#    'value': 1.0},
#   {'descrip': 'PhS->MZL  Feeding preference',
#    'param': 'fpPhSMZL',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'PhL->MZL  Feeding preference',
#    'param': 'fpPhLMZL',
#    'unit': None,
#    'value': 0.2},
#   {'descrip': 'PhS->Cop  Feeding preference',
#    'param': 'fpPhSCop',
#    'unit': None,
#    'value': 0.8},
#   {'descrip': 'PhL->Cop  Feeding preference',
#    'param': 'fpPhLCop',
#    'unit': None,
#    'value': 0.7},
#   {'descrip': 'MZL->Cop  Feeding preference',
#    'param': 'fpMZLCop',
#    'unit': None,
#    'value': 0.5},
#   {'descrip': 'PhS->NCa  Feeding preference',
#    'param': 'fpPhSNCa',
#    'unit': None,
#    'value': 0.1},
#   {'descrip': 'PhL->NCa  Feeding preference',
#    'param': 'fpPhLNCa',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'MZL->NCa  Feeding preference',
#    'param': 'fpMZLNCa',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'PhS->Eup  Feeding preference',
#    'param': 'fpPhSEup',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'PhL->Eup  Feeding preference',
#    'param': 'fpPhLEup',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'MZL->Eup  Feeding preference',
#    'param': 'fpMZLEup',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'Cop->Eup  Feeding preference',
#    'param': 'fpCopEup',
#    'unit': None,
#    'value': 0.2},
#   {'descrip': 'Det->Eup  Feeding preference',
#    'param': 'fpDetEup',
#    'unit': None,
#    'value': 0.4},
#   {'descrip': 'Det->EupO Feeding preference',
#    'param': 'fpDetEupO',
#    'unit': None,
#    'value': 0.0},
#   {'descrip': 'Cop->Jel  Feeding preference',
#    'param': 'fpCopJel',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'NCa->Jel  Feeding preference',
#    'param': 'fpNCaJel',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'Eup->Jel  Feeding preference',
#    'param': 'fpEupJel',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'maximum specific ingestion rate',
#    'param': 'eMZL',
#    'unit': 'mg C/mg C/d',
#    'value': 0.4},
#   {'descrip': 'maximum specific ingestion rate',
#    'param': 'eCop',
#    'unit': 'mg C/mg C/d',
#    'value': 0.4},
#   {'descrip': 'maximum specific ingestion rate',
#    'param': 'eNCa',
#    'unit': 'mg C/mg C/d',
#    'value': 0.3},
#   {'descrip': 'maximum specific ingestion rate',
#    'param': 'eEup',
#    'unit': 'mg C/mg C/d',
#    'value': 0.3},
#   {'descrip': 'maximum specific ingestion rate',
#    'param': 'eJel',
#    'unit': 'mg C/mg C/d',
#    'value': 0.069},
#   {'descrip': 'Q10 for growth rate',
#    'param': 'Q10MZL',
#    'unit': 'unitless',
#    'value': 2.0},
#   {'descrip': 'Q10 for growth rate',
#    'param': 'Q10Cop',
#    'unit': 'unitless',
#    'value': 1.7},
#   {'descrip': 'Q10 for growth rate',
#    'param': 'Q10NCa',
#    'unit': 'unitless',
#    'value': 1.6},
#   {'descrip': 'Q10 for growth rate',
#    'param': 'Q10Eup',
#    'unit': 'unitless',
#    'value': 1.5},
#   {'descrip': 'Q10 for growth rate',
#    'param': 'Q10Jele',
#    'unit': 'unitless',
#    'value': 2.4},
#   {'descrip': 'Temperature coefficient for Q10',
#    'param': 'Q10MZLT',
#    'unit': 'deg. C',
#    'value': 5.0},
#   {'descrip': 'Temperature coefficient for Q10',
#    'param': 'Q10CopT',
#    'unit': 'deg. C',
#    'value': 5.0},
#   {'descrip': 'Temperature coefficient for Q10',
#    'param': 'Q10NCaT',
#    'unit': 'deg. C',
#    'value': 5.0},
#   {'descrip': 'Temperature coefficient for Q10',
#    'param': 'Q10EupT',
#    'unit': 'deg. C',
#    'value': 5.0},
#   {'descrip': 'Temperature coefficient for Q10',
#    'param': 'Q10JelTe',
#    'unit': 'deg. C',
#    'value': 10.0},
#   {'descrip': 'Half-saturation constant for grazing',
#    'param': 'fMZL',
#    'unit': 'mg C/m3',
#    'value': 20.0},
#   {'descrip': 'Half-saturation constant for grazing',
#    'param': 'fCop',
#    'unit': 'mg C/m3',
#    'value': 30.0},
#   {'descrip': 'Half-saturation constant for grazing',
#    'param': 'fNCa',
#    'unit': 'mg C/m3',
#    'value': 30.0},
#   {'descrip': 'Half-saturation constant for grazing',
#    'param': 'fEup',
#    'unit': 'mg C/m3',
#    'value': 40.0},
#   {'descrip': 'Half-saturation constant for grazing',
#    'param': 'fJel',
#    'unit': 'mg C/m3',
#    'value': 0.01},
#   {'descrip': 'Growth efficiency',
#    'param': 'gammaMZL',
#    'unit': None,
#    'value': 0.7},
#   {'descrip': 'Growth efficiency',
#    'param': 'gammaCop',
#    'unit': None,
#    'value': 0.7},
#   {'descrip': 'Growth efficiency',
#    'param': 'gammaNCa',
#    'unit': None,
#    'value': 0.7},
#   {'descrip': 'Growth efficiency',
#    'param': 'gammaEup',
#    'unit': None,
#    'value': 0.7},
#   {'descrip': 'Growth efficiency',
#    'param': 'gammaJel',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'daily linear mortality rate (senescence)',
#    'param': 'mPhS',
#    'unit': '1/d',
#    'value': 0.01},
#   {'descrip': 'daily linear mortality rate (senescence)',
#    'param': 'mPhL',
#    'unit': '1/d',
#    'value': 0.01},
#   {'descrip': 'daily linear mortality rate',
#    'param': 'mMZL',
#    'unit': '1/d',
#    'value': 0.0},
#   {'descrip': 'Daily mortality for Large Microzoo.',
#    'param': 'mpredMZL',
#    'unit': '1/d/mgC',
#    'value': 0.01},
#   {'descrip': 'Daily mortality for Copepods',
#    'param': 'mpredCop',
#    'unit': '1/d/mgC',
#    'value': 0.05},
#   {'descrip': 'Daily mortality for Neocalanus',
#    'param': 'mpredNCa',
#    'unit': '1/d/mgC',
#    'value': 0.05},
#   {'descrip': 'Daily mortality for Euphausiids',
#    'param': 'mpredEup',
#    'unit': '1/d/mgC',
#    'value': 0.05},
#   {'descrip': 'Daily mortality for Large Microzoo.',
#    'param': 'mpredJel',
#    'unit': '1/d/mgC',
#    'value': 0.006},
#   {'descrip': 'Sinking rate for Small Phytoplankton',
#    'param': 'wPhS',
#    'unit': 'm/d',
#    'value': 0.05},
#   {'descrip': 'Sinking rate for Large Phytoplankton',
#    'param': 'wPhL',
#    'unit': 'm/d',
#    'value': 1.0},
#   {'descrip': 'Sinking rate for Detritus',
#    'param': 'wDet',
#    'unit': 'm/d',
#    'value': 1.0},
#   {'descrip': 'Sinking rate for Detritus',
#    'param': 'wDetF',
#    'unit': 'm/d',
#    'value': 10.0},
#   {'descrip': 'Specific respiration rate',
#    'param': 'respPhS',
#    'unit': 'd^-1',
#    'value': 0.02},
#   {'descrip': 'Specific respiration rate',
#    'param': 'respPhL',
#    'unit': 'd^-1',
#    'value': 0.02},
#   {'descrip': 'Specific respiration rate',
#    'param': 'respMZL',
#    'unit': 'd^-1',
#    'value': 0.08},
#   {'descrip': 'Specific respiration rate',
#    'param': 'respCop',
#    'unit': 'd^-1',
#    'value': 0.04},
#   {'descrip': 'Specific respiration rate',
#    'param': 'respNCa',
#    'unit': 'd^-1',
#    'value': 0.03},
#   {'descrip': 'Specific respiration rate',
#    'param': 'respEup',
#    'unit': 'd^-1',
#    'value': 0.02},
#   {'descrip': 'Specific respiration rate',
#    'param': 'respJel',
#    'unit': 'd^-1',
#    'value': 0.02},
#   {'descrip': 'Q10 for respiration rate, jellyfish',
#    'param': 'Q10Jelr',
#    'unit': 'degC',
#    'value': 2.8},
#   {'descrip': 'reference temperature for Q10 respiration, jellyfish',
#    'param': 'Q10JelTr',
#    'unit': '1/degC',
#    'value': 10.0},
#   {'descrip': 'temperature coefficient for respiration',
#    'param': 'KtBm_PhS',
#    'unit': '1/deg C',
#    'value': 0.03},
#   {'descrip': 'temperature coefficient for respiration',
#    'param': 'KtBm_PhL',
#    'unit': '1/deg C',
#    'value': 0.03},
#   {'descrip': 'temperature coefficient for respiration',
#    'param': 'KtBm_MZL',
#    'unit': '1/deg C',
#    'value': 0.069},
#   {'descrip': 'temperature coefficient for respiration',
#    'param': 'ktbmC',
#    'unit': '1/deg C',
#    'value': 0.05},
#   {'descrip': 'temperature coefficient for respiration',
#    'param': 'ktbmN',
#    'unit': '1/deg C',
#    'value': 0.05},
#   {'descrip': 'temperature coefficient for respiration',
#    'param': 'ktbmE',
#    'unit': '1/deg C',
#    'value': 0.069},
#   {'descrip': 'reference temperature for respiration',
#    'param': 'TmaxPhS',
#    'unit': 'degC',
#    'value': 10.0},
#   {'descrip': 'reference temperature for respiration',
#    'param': 'TmaxPhL',
#    'unit': 'degC',
#    'value': 10.0},
#   {'descrip': 'reference temperature for respiration',
#    'param': 'TmaxMZL',
#    'unit': 'degC',
#    'value': 8.0},
#   {'descrip': 'reference temperature for respiration',
#    'param': 'TrefC',
#    'unit': 'degC',
#    'value': 15.0},
#   {'descrip': 'reference temperature for respiration',
#    'param': 'TrefN',
#    'unit': 'degC',
#    'value': 5.0},
#   {'descrip': 'reference temperature for respiration',
#    'param': 'TrefE',
#    'unit': 'degC',
#    'value': 5.0},
#   {'descrip': 'inshore/surface',
#    'param': 'Feinlo',
#    'unit': 'micromol Fe m-3 or nM',
#    'value': 2.0},
#   {'descrip': 'inshore/deep',
#    'param': 'Feinhi',
#    'unit': 'micromol Fe m-3 or nM',
#    'value': 4.0},
#   {'descrip': 'inshore isobath of transition',
#    'param': 'Feinh',
#    'unit': 'm',
#    'value': 20.0},
#   {'descrip': 'offshore/surface',
#    'param': 'Feofflo',
#    'unit': 'micromol Fe m-3 or nM',
#    'value': 0.01},
#   {'descrip': 'offshore/deep',
#    'param': 'Feoffhi',
#    'unit': 'micromol Fe m-3 or nM',
#    'value': 2.0},
#   {'descrip': 'offshore isobath of transition',
#    'param': 'Feoffh',
#    'unit': 'm',
#    'value': 100.0},
#   {'descrip': 'upward velocity , tuned not data',
#    'param': 'wNCrise',
#    'unit': 'm/day',
#    'value': 12.0},
#   {'descrip': 'downward velocity , tuned not data',
#    'param': 'wNCsink',
#    'unit': 'm/day',
#    'value': 11.0},
#   {'descrip': 'Date NCaO begin to move upward',
#    'param': 'RiseStart',
#    'unit': 'Day of Year',
#    'value': 0.0},
#   {'descrip': 'Date NCaO stop moving upward',
#    'param': 'RiseEnd',
#    'unit': 'Day of Year',
#    'value': 60.0},
#   {'descrip': 'Date NCaO begin to move downward',
#    'param': 'SinkStart',
#    'unit': 'Day of Year',
#    'value': 155.0},
#   {'descrip': 'Date NCaO stop moving downward',
#    'param': 'SinkEnd',
#    'unit': 'Day of Year',
#    'value': 366.0},
#   {'descrip': 'Date NCaS begin to move upward',
#    'param': 'RiseStartCM',
#    'unit': 'Day of Year',
#    'value': 0.0},
#   {'descrip': 'Date NCaS stop moving upward',
#    'param': 'RiseEndCM',
#    'unit': 'Day of Year',
#    'value': 0.0},
#   {'descrip': 'Date NCaS begin to move downward',
#    'param': 'SinkStartCM',
#    'unit': 'Day of Year',
#    'value': 0.0},
#   {'descrip': 'Date NCaS stop moving downward',
#    'param': 'SinkEndCM',
#    'unit': 'Day of Year',
#    'value': 0.0},
#   {'descrip': 'PON decompositon at 0 deg C',
#    'param': 'Pv0',
#    'unit': '1/d',
#    'value': 0.1},
#   {'descrip': 'Temperature coefficient for remineralization',
#    'param': 'PvT',
#    'unit': '1/deg C',
#    'value': 0.069},
#   {'descrip': 'Nitrification rate at 0C',
#    'param': 'Nitr0',
#    'unit': '1/d',
#    'value': 0.0107},
#   {'descrip': 'Temperature coefficient for nitrification',
#    'param': 'ktntr',
#    'unit': '1/deg C',
#    'value': 0.002},
#   {'descrip': 'Half saturation constant for nitrification',
#    'param': 'KNH4Nit',
#    'unit': 'mmolN/m^3',
#    'value': 0.057},
#   {'descrip': 'Optimal temperature for nitrification',
#    'param': 'ToptNtr',
#    'unit': 'degC',
#    'value': 20.0},
#   {'descrip': 'Q10 for growth/feeding and mortality rate',
#    'param': 'q10r',
#    'unit': 'unitless',
#    'value': 1.5},
#   {'descrip': 'maximum specific ingestion rate',
#    'param': 'Rup',
#    'unit': '1/d',
#    'value': 0.05},
#   {'descrip': 'Half-saturation constant for feeding on benthic prey',
#    'param': 'KupD',
#    'unit': 'mg C/m^2',
#    'value': 2000.0},
#   {'descrip': 'Half-saturation constant for feeding on pelagic prey',
#    'param': 'KupP',
#    'unit': 'mg C/m^2',
#    'value': 10.0},
#   {'descrip': 'Lower threshold for feeding on benthic prey',
#    'param': 'LupD',
#    'unit': 'mg C/m^2',
#    'value': 292.0},
#   {'descrip': 'Lower threshold for feeding on pelagic prey',
#    'param': 'LupP',
#    'unit': 'mg C/m^2',
#    'value': 1.0},
#   {'descrip': 'Active metabolic rate',
#    'param': 'Qres',
#    'unit': '1/d',
#    'value': 0.25},
#   {'descrip': 'Basal metabolism rate',
#    'param': 'Rres',
#    'unit': '1/d',
#    'value': 0.0027},
#   {'descrip': 'linear mortality rate',
#    'param': 'rmort',
#    'unit': '1/d',
#    'value': 0.0021},
#   {'descrip': 'fraction of living food excreted (1 - growth efficiency)',
#    'param': 'eex',
#    'unit': None,
#    'value': 0.3},
#   {'descrip': 'fraction of detrital food excreted',
#    'param': 'eexD',
#    'unit': None,
#    'value': 0.5},
#   {'descrip': 'DetBen->Ben feeding preference',
#    'param': 'prefD',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'PhL->Ben feeding preference',
#    'param': 'prefPL',
#    'unit': None,
#    'value': 1.0},
#   {'descrip': 'PhS->Ben feeding preference',
#    'param': 'prefPS',
#    'unit': None,
#    'value': 0.1},
#   {'descrip': 'Reference temperature for growth/feeding rate',
#    'param': 'T0benr',
#    'unit': 'degC',
#    'value': 5.0},
#   {'descrip': 'Quadratic mortality rate due to undefined predation',
#    'param': 'BenPred',
#    'unit': '1/mgC/d',
#    'value': 1e-06},
#   {'descrip': 'IcePhL Chl-a specific attenuation coefficient',
#    'param': 'alphaIb',
#    'unit': 'W^-1 m^-2',
#    'value': 0.8},
#   {'descrip': 'IcePhL photosynthetic efficiency',
#    'param': 'betaI',
#    'unit': 'W^-1 m^-2',
#    'value': 0.018},
#   {'descrip': 'IcePhL NH4 inhibition on NO3 uptake',
#    'param': 'inhib',
#    'unit': 'm^3/mmol N',
#    'value': 1.46},
#   {'descrip': 'IcePhL half-saturation constant for NO3',
#    'param': 'ksnut1',
#    'unit': 'mmolN/m^3',
#    'value': 1.0},
#   {'descrip': 'IcePhL half-saturation constant for NH4',
#    'param': 'ksnut2',
#    'unit': 'mmolN/m^3',
#    'value': 4.0},
#   {'descrip': 'IcePhL maximum growth rate at 0 deg C',
#    'param': 'mu0',
#    'unit': '1/d',
#    'value': 2.4},
#   {'descrip': 'IcePhL respiration rate',
#    'param': 'R0i',
#    'unit': '1/d',
#    'value': 0.05},
#   {'descrip': 'IcePhL mortality rate at 0 deg C',
#    'param': 'rg0',
#    'unit': '1/d',
#    'value': 0.01},
#   {'descrip': 'IcePhL temperature coefficient for mortality',
#    'param': 'rg',
#    'unit': '1/deg C',
#    'value': 0.03},
#   {'descrip': 'IcePhL nitrification factor',
#    'param': 'annit',
#    'unit': '1/d',
#    'value': 0.0149},
#   {'descrip': 'Ice thickness', 'param': 'aidz', 'unit': 'm', 'value': 0.02},
#   {'descrip': 'Nitrification light threshold',
#    'param': 'tI0',
#    'unit': 'W m^-2',
#    'value': 0.0095},
#   {'descrip': 'Nitrification light half-saturation constant',
#    'param': 'KI',
#    'unit': 'W m^-2',
#    'value': 4.0}]}
